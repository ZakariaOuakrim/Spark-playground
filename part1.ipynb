# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("Dataframe").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/09/22 15:30:20 WARN Utils: Your hostname, codespaces-27303d, resolves to a loopback address: 127.0.0.1; using 10.0.1.167 instead (on interface eth0)
# 25/09/22 15:30:20 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/09/22 15:30:21 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/09/22 15:30:22 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://e87c4c74-4400-4962-bfd0-684586497a83.internal.cloudapp.net:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
## read dataset 
df_spark=spark.read.option("header","True").csv("test1.csv",inferSchema=True)
df_spark.show()
# Out:
# +--------+---+----------+
# |    name|age|experience|
# +--------+---+----------+
# | Zakaria| 23|         1|
# | khadija| 27|         4|
# |abdellah| 57|        20|
# |   Ilyas| 21|         1|
# +--------+---+----------+

# %%
## check schema
df_spark.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- experience: integer (nullable = true)

# %%
df_spark.columns
# Out:
# ['name', 'age', 'experience']

# %%
df_spark.head()
# Out:
# Row(name='Zakaria', age=23, experience=1)

# %%
df_spark.show()
# Out:
# +--------+---+----------+
# |    name|age|experience|
# +--------+---+----------+
# | Zakaria| 23|         1|
# | khadija| 27|         4|
# |abdellah| 57|        20|
# |   Ilyas| 21|         1|
# +--------+---+----------+

# %%
df_spark.select("Name","experience").show()
# Out:
# +--------+----------+
# |    Name|experience|
# +--------+----------+
# | Zakaria|         1|
# | khadija|         4|
# |abdellah|        20|
# |   Ilyas|         1|
# +--------+----------+

# %%
df_spark.dtypes
# Out:
# [('name', 'string'), ('age', 'int'), ('experience', 'int')]

# %%
## add a column 
df_spark=df_spark.withColumn("Experience after two years",df_spark["experience"]+2)

# %%
df_spark.show()
# Out:
# +--------+---+----------+--------------------------+
# |    name|age|experience|Experience after two years|
# +--------+---+----------+--------------------------+
# | Zakaria| 23|         1|                         3|
# | khadija| 27|         4|                         6|
# |abdellah| 57|        20|                        22|
# |   Ilyas| 21|         1|                         3|
# +--------+---+----------+--------------------------+

# %%
# drop columns 
df_spark=df_spark.drop("Experience after two years")

# %%
df_spark.show()
# Out:
# +--------+---+----------+
# |    name|age|experience|
# +--------+---+----------+
# | Zakaria| 23|         1|
# | khadija| 27|         4|
# |abdellah| 57|        20|
# |   Ilyas| 21|         1|
# +--------+---+----------+

# %%
# rename columns 
df_spark.withColumnRenamed("Name",'real name')
# Out:
# DataFrame[real name: string, age: int, experience: int]
