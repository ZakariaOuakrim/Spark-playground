# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-4.0.1.tar.gz (434.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.2/434.2 MB 29.3 MB/s  0:00:09:00:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting py4j==0.10.9.9 (from pyspark)
#   Downloading py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (pyproject.toml) ... done
#   Created wheel for pyspark: filename=pyspark-4.0.1-py2.py3-none-any.whl size=434813860 sha256=b3cec8adae7952a349c098ab41ec5c07c220a067c1809c7d01e7c71864ce6fc3
#   Stored in directory: /home/codespace/.cache/pip/wheels/31/9f/68/f89fb34ccd886909be7d0e390eaaf97f21efdf540c0ee8dbcd
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pyspark]m1/2 [pyspark]
# Successfully installed py4j-0.10.9.9 pyspark-4.0.1

# %%
import pyspark

# %%
import pandas as pd 
pd.read_csv('test1.csv')
# Out:
#        name  age
# 0   Zakaria   23
# 1   khadija   27
# 2  abdellah   57
# 3     Ilyas   21

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName("Practice").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://e87c4c74-4400-4962-bfd0-684586497a83.internal.cloudapp.net:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.option('header','true').csv("test1.csv")
df_pyspark.show()
# Out:
# +--------+---+
# |    name|age|
# +--------+---+
# | Zakaria| 23|
# | khadija| 27|
# |abdellah| 57|
# |   Ilyas| 21|
# +--------+---+

# %%
type(df_pyspark)

df_pyspark.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- age: string (nullable = true)
